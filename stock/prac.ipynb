# %% [markdown]
# 1. Basic Stock Data Retrieval
# 2. Access News Headlines
# 3. Plotting Stock Data
# 4. Getting Company Information
#
#
# 🔍 Next Step: Stock Price Data via yfinance
#
# Let’s begin with the easier win: get recent TSLA price data (say, for the past 7 days).
# 🎯 Your Task:
#
#     Use yfinance to pull daily close prices for TSLA over the last 7 days.
#
#     Make sure the result is clean: a table with dates and closing prices only.
#
# 💡 Hints to Think About:
#
#     How do you define "last 7 days"? Is that trading days or calendar days?
#
#     What type of data structure does yfinance.download() return?
#
#     How do you isolate just the Close price column?
#
# Once you’ve got the data pulled and formatted, let me know:
#
#     What it looks like
#
#     Any challenges you hit
#
# I’ll review and guide you toward integrating it with sentiment data.

# %%
# Pull daily close prices for TSLA over last 7 days

import yfinance as yf
import matplotlib.pyplot as plt

recent_data = yf.download("TSLA", period="7D", auto_adjust=True)
recent_data['Close'].plot(label="TSLA")
plt.legend(title="Ticker")
plt.title("Tesla Closing Prices Across Last 7 Days")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="tiingo.env")
api_key = os.getenv("tiingo_key")

print(api_key)
# Out:
# a58902ea4b75d77449a96c904bbc14b33a54bb93

# %%
# GET TSLA price data from Tiingo
import requests

ticker = "TSLA"
url = f"https://api.tiingo.com/tiingo/daily/{ticker}/prices?startDate=2024-05-01&endDate=2024-06-13"

headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Token {api_key}'
}

response = requests.get(url, headers=headers)
price_data = response.json()

import pandas as pd
df = pd.DataFrame(price_data)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df.head()
# Out:
#                             close    high     low    open    volume  adjClose  \
# date
# 2024-05-01 00:00:00+00:00  179.99  185.86  179.01  182.00  92829719    179.99
# 2024-05-02 00:00:00+00:00  180.01  184.60  176.02  182.86  89148041    180.01
# 2024-05-03 00:00:00+00:00  181.19  184.78  178.42  182.10  75491539    181.19
# 2024-05-06 00:00:00+00:00  184.76  187.56  182.20  183.80  84390253    184.76
# 2024-05-07 00:00:00+00:00  177.81  183.26  177.40  182.40  75045854    177.81
#
#                            adjHigh  adjLow  adjOpen  adjVolume  divCash  \
# date
# 2024-05-01 00:00:00+00:00   185.86  179.01   182.00   92829719      0.0
# 2024-05-02 00:00:00+00:00   184.60  176.02   182.86   89148041      0.0
# 2024-05-03 00:00:00+00:00   184.78  178.42   182.10   75491539      0.0
# 2024-05-06 00:00:00+00:00   187.56  182.20   183.80   84390253      0.0
# 2024-05-07 00:00:00+00:00   183.26  177.40   182.40   75045854      0.0
#
#                            splitFactor
# date
# ...
